# %% [markdown]
# ## Lab 9
# ### *Hasan Ravda [ 216270307028 ]*

# %% [markdown]
# ## Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and Volume of given company between two specific dates.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/kaggle/input/stock-market-data-nifty-50-2000-2022/Nifty_50_with_indicators_.csv')
df=pd.read_csv('/kaggle/input/tesla-stock-data-updated-till-28jun2021/TSLA.csv')
# df.sort_values(by=['Date'],ascending=False)
df

# %%
df2=df.iloc[:-10:-1]
# df2.plot(x='Date',y=['Open','High','Low','Close','Adj Close','Volume'])
df2.plot(x='Date',y=['Open','High','Low','Close','Adj Close'])

# %%
df_50=df2.iloc[:-50:-1]
df_50.plot(x='Date',y='Volume',kind='bar')
